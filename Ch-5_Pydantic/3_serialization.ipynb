# %%
from pydantic import BaseModel, Field,EmailStr
from typing import Optional, Literal

class employee_schema(BaseModel):

    name:str=Field(...,min_length=3,max_length=50)
    age:int=Field(...,gt=18,lt=65)
    email:EmailStr=Field(...,description="Employee's email address")
    department:Optional[str]=None
    gender:Literal['Male','Female','Other']=Field(...,description="Employee's gender")

# %%
obj=employee_schema(name="John Doe",age=30,email="john.doe@example.com",gender="Male")
obj
# Out:
# employee_schema(name='John Doe', age=30, email='john.doe@example.com', department=None, gender='Male')

# %% [markdown]
# ## Serialization

# %%
obj.model_dump()

# %%
obj.model_dump_json()
